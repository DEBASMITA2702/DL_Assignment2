# %%
# !pip install pytorch-lightning wandb torchmetrics

# %%
# %%writefile ModelPreTrained_Base.py
import torch
import torchvision
import torch.nn as nn
import lightning as pl
import re
import torchmetrics
import torch.optim as optim
from torchvision.models import GoogLeNet_Weights

"""Base class to perform fine tuning on a pre-trained model.
This class initializes the pre-trained GoogLeNet model, freezes layers, sets up the feature extractor and attaches a new output layer to match the number of classes."""
class FineTuningModelBase(pl.LightningModule):
    """Constructor to set all the class parameters and initialize the pre-trained model."""
    def __init__(self, numClasses, numOfFreezedLayers, learning_rate, aux_logits=True):
        super(FineTuningModelBase, self).__init__()
        
        '''loads the GoogLeNet model'''
        self.model=torchvision.models.googlenet(pretrained=True)
        self.numOfFreezedLayers=numOfFreezedLayers
        self.learning_rate=learning_rate

        """Freezes the layers based on the specified number of layers to freeze."""
        for n, p in self.model.named_parameters():
            match = re.search(r'\d+', n.split('.')[0])
            if match and int(match.group()) < self.numOfFreezedLayers:
                p.requires_grad = False
        
        """Extracts the layers excluding the final fully-connected layer as a feature extractor."""
        numOfLayers = list(self.model.children())[:-1]
        self.feature_extractor = nn.Sequential(*numOfLayers)
        self.feature_extractor.eval()

        """Adding a new layer to match the output dimensions to the number of classes in the iNaturalist dataset."""
        inFeatures = self.model.fc.in_features
        self.outputLayer = nn.Linear(inFeatures, numClasses)

        """The cross-entropy loss function."""
        self.criterion = nn.CrossEntropyLoss()

        """Initializes metrics for training and validation accuracies and a variable for test accuracy."""
        self.training_accuracy = torchmetrics.Accuracy(task="multiclass", num_classes=numClasses)
        self.validation_accuracy = torchmetrics.Accuracy(task="multiclass", num_classes=numClasses)
        self.test_accuracy = 0
        
    def forward(self, x):
        """
        Parameters:
            x: Input tensor for forward propagation.
        Returns:
            x: Output tensor after applying the forward propagation.
        Function:
            Flattens the features extracted by the feature extractor and applies the output layer.
        """
        flattened = self.feature_extractor(x).flatten(1)
        x = self.outputLayer(flattened)
        return x
    
    def configure_optimizers(self):
        """
        Parameters:
            None
        Returns:
            optimizer: Optimizer object for training the network.
        Function:
            Creates and returns an Adam optimizer using the model parameters and the specified learning rate.
        """
        optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)
        return optimizer
# Out:
# Writing ModelPreTrained_Base.py

# %%
# !pip install lightning
# Out:
# Collecting lightning
#   Downloading lightning-2.5.1-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.11/dist-packages (from lightning) (6.0.2)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (2025.3.2)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (0.14.3)
# Requirement already satisfied: packaging<25.0,>=20.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (24.2)
# Requirement already satisfied: torch<4.0,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (2.5.1+cu124)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (1.7.1)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (4.13.1)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.11/dist-packages (from lightning) (2.5.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (3.11.16)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities<2.0,>=0.10.0->lightning) (75.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<4.0,>=2.1.0->lightning) (1.3.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics<3.0,>=0.7.0->lightning) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.19.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>1.20.0->torchmetrics<3.0,>=0.7.0->lightning) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>1.20.0->torchmetrics<3.0,>=0.7.0->lightning) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>1.20.0->torchmetrics<3.0,>=0.7.0->lightning) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>1.20.0->torchmetrics<3.0,>=0.7.0->lightning) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>1.20.0->torchmetrics<3.0,>=0.7.0->lightning) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>1.20.0->torchmetrics<3.0,>=0.7.0->lightning) (2.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<4.0,>=2.1.0->lightning) (3.0.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (3.10)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>1.20.0->torchmetrics<3.0,>=0.7.0->lightning) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>1.20.0->torchmetrics<3.0,>=0.7.0->lightning) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>1.20.0->torchmetrics<3.0,>=0.7.0->lightning) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>1.20.0->torchmetrics<3.0,>=0.7.0->lightning) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>1.20.0->torchmetrics<3.0,>=0.7.0->lightning) (2024.2.0)
# Downloading lightning-2.5.1-py3-none-any.whl (818 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 818.9/818.9 kB 17.8 MB/s eta 0:00:0000:01
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.5 MB/s eta 0:00:0000:01m00:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.2 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 67.4 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, lightning
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.9.90
#     Uninstalling nvidia-curand-cu12-10.3.9.90:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pylibcugraph-cu12 24.12.0 requires pylibraft-cu12==24.12.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 24.12.0 requires rmm-cu12==24.12.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed lightning-2.5.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# %%writefile ModelPreTrained_test.py
import torch
from ModelPreTrained_train_val import FineTuningModelTrainVal

"""Extending FineTuningModelTrainVal by adding the test step method"""
class FineTuningModel(FineTuningModelTrainVal):
    """Inherits from FineTuningModelTrainVal and implements the test_step method"""
    
    def test_step(self, batch, batch_idx):
        """
        Parameters:
            batch: A batch of test data (input tensor and labels).
            batch_idx: Batch index.
        Returns:
            accuracy: Test accuracy for the processed batch.
        Function:
            Performs a test step by processing the input, determining the predicted class,
            calculating the batch accuracy, and accumulating the test accuracy.
        """
        x, y = batch
        y_hat = self(x)
        predicted = torch.argmax(y_hat, dim=1)
        correct_points = (predicted == y).sum().item()
        total_points = len(y)
        accuracy = correct_points / total_points
        self.test_accuracy += accuracy
        return accuracy
# Out:
# Writing ModelPreTrained_test.py

# %%
# %%writefile LoadDataset.py
import torch
import torchvision
from torchvision import transforms
import os
from torch.utils.data import random_split

'''class to load the dataset'''
class DatasetLoader:
    '''constructor to set all the class parameters'''
    def __init__(self, root, batch_size):
        '''path of the dataset'''
        self.root = root
        '''batch size'''
        self.batch_size = batch_size
        '''transformation to apply on the dataset'''
        self.transform = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.4747786223888397, 0.4644955098628998, 0.3964916169643402],std=[0.2389, 0.2289, 0.2422]),
        ])
        self.train_dataset, self.val_dataset, self.test_dataset = self.load_and_split_datasets()

    def load_and_split_datasets(self):
        '''
        Parameters:
            None
        Function:
            Loads and splits the original dataset
        Returns:
            train_dataset: dataset for training
            val_dataset: dataset for validation
            test_dataset: dataset for testing
        '''
        train_path = ''
        test_path = ''
        train_path = os.path.join(self.root, "train")
        test_path = os.path.join(self.root, "val")
        train_val_dataset = torchvision.datasets.ImageFolder(root=train_path, transform=self.transform)
        
        '''splitting into train and val'''
        train_size = int(0.8 * len(train_val_dataset))
        val_size = len(train_val_dataset) - train_size
        train_dataset, val_dataset = random_split(train_val_dataset, [train_size, val_size])
        
        test_dataset = torchvision.datasets.ImageFolder(root=test_path, transform=self.transform)
        return train_dataset, val_dataset, test_dataset
# Out:
# Writing LoadDataset.py

# %%
# %%writefile Create_DataLoader.py
from LoadDataset import DatasetLoader
from torch.utils.data import DataLoader

'''This class inherits from DatasetLoader and adds the data_loaders method.'''
class DatasetLoader_create(DatasetLoader):
    '''This class inherits from DatasetLoader and adds the data_loaders method.'''
    def data_loaders(self):
        '''
        Parameters:
            None
        Function:
            Creates DataLoader objects for training, validation, and testing (creates a one hot vector).
        Returns:
            train_loader : Data loader object of torch to be used for training
            val_loader : Data loader object of torch to be used for validation
            test_loader : Data loader object of torch to be used for testing
        '''
        train_loader = DataLoader(self.train_dataset, batch_size=self.batch_size, shuffle=True)
        val_loader = DataLoader(self.val_dataset, batch_size=self.batch_size, shuffle=False)
        test_loader = DataLoader(self.test_dataset, batch_size=self.batch_size, shuffle=False)
        return train_loader, val_loader, test_loader
# Out:
# Writing Create_DataLoader.py

# %%
# %%writefile ModelPreTrained_train_val.py
from ModelPreTrained_Base import FineTuningModelBase

"""Extending FineTuningModelBase by adding the training and validation methods."""
class FineTuningModelTrainVal(FineTuningModelBase):
    """Inherits from FineTuningModelBase and implements training and validation methods."""
    
    def training_step(self, batch, batch_idx):
        """
        Parameters:
            batch: A batch of training data (input tensor and labels).
            batch_idx: Batch index.
        Returns:
            loss: Loss value calculated after forward propagation and loss computation.
        Function:
            Performs a training step by processing the input, computing the loss, updating training metrics, and logging the loss.
        """
        x, y = batch
        y_hat = self(x)
        loss = self.criterion(y_hat, y)
        self.training_accuracy(y_hat, y)
        self.log("training_loss", loss, on_step=False, on_epoch=True, prog_bar=True, logger=True)
        return loss
    
    def on_train_epoch_end(self):
        """
        Parameters:
            None
        Returns:
            training accuracy after resetting the training metric.
        Function:
            Logs the training accuracy at the end of an epoch and resets the training accuracy metric.
        """
        accuracy = self.training_accuracy.compute()
        self.log('training_accuracy', accuracy, prog_bar=True, logger=True, sync_dist=True)
        return self.training_accuracy.reset()
    
    def validation_step(self, batch, batch_idx):
        """
        Parameters:
            batch: A batch of validation data (input tensor and labels).
            batch_idx: Batch index.
        Returns:
            loss: Loss value calculated on the validation batch.
        Function:
            Performs a validation step by processing the input, computing the loss, updating validation metrics, and logging the loss.
        """
        x, y = batch
        y_hat = self(x)
        loss = self.criterion(y_hat, y)
        self.validation_accuracy(y_hat, y)
        self.log("validation_loss", loss, on_step=False, on_epoch=True, prog_bar=True, logger=True)
        return loss
    
    def on_validation_epoch_end(self):
        """
        Parameters:
            None
        Returns:
            validation accuracy after resetting the validation metric.
        Function:
            Logs the validation accuracy at the end of an epoch and resets the validation accuracy metric.
        """
        accuracy = self.validation_accuracy.compute()
        self.log('validation_accuracy', accuracy, prog_bar=True, logger=True, sync_dist=True)
        return self.validation_accuracy.reset()
# Out:
# Writing ModelPreTrained_train_val.py

# %%
# %%writefile Question3.py
import Create_DataLoader
import ModelPreTrained_test
import lightning as pl

'''function to the pre trained model'''
def main():   
    '''
        defining parameteres and loading the dataset
        The values of the parameters are set according to the best model that I had achieved
    ''' 
    batch_size=16
    dataLoader=Create_DataLoader.DatasetLoader_create(root='/kaggle/input/inaturalist-12k/nature_12K_dataset/inaturalist_12K',batch_size=batch_size)
    trainLoader,valLoader,testLoader=dataLoader.data_loaders()
    
    freezed_layers=5
    learning_rate=1e-4
    numOfOutputClasses=10
    epochs=20

    '''creating object of the FineTuningModel class'''
    preTrainedModel=ModelPreTrained_test.FineTuningModel(numOfOutputClasses,freezed_layers,learning_rate)
    
    '''creating trainer object by pytorch lightning'''
    #trainer=pl.Trainer(max_epochs=epochs)
    trainer = pl.Trainer(max_epochs=epochs,strategy="ddp_find_unused_parameters_true",devices=1, enable_progress_bar=True)

    '''exectuing training and validartion step'''
    trainer.fit(preTrainedModel,trainLoader,valLoader)

    '''executing test step and reporting test accuracy'''
    trainer.test(preTrainedModel,testLoader)
    print("Test Accuracy : ",preTrainedModel.test_accuracy/len(testLoader))

if __name__ == '__main__':
    main()
# Out:
# Writing Question3.py

# %%
# !python Question3.py
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=GoogLeNet_Weights.IMAGENET1K_V1`. You can also use `weights=GoogLeNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/googlenet-1378be20.pth" to /root/.cache/torch/hub/checkpoints/googlenet-1378be20.pth
# 100%|███████████████████████████████████████| 49.7M/49.7M [00:00<00:00, 206MB/s]
# INFO: You are using the plain ModelCheckpoint callback. Consider using LitModelCheckpoint which with seamless uploading to Model registry.
# INFO: GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO: Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# INFO: ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# 2025-04-17 11:40:43.279956: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744890043.466334     114 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744890043.522393     114 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# INFO:
#   | Name                | Type               | Params | Mode
# -------------------------------------------------------------------
# 0 | model               | GoogLeNet          | 6.6 M  | train
# 1 | feature_extractor   | Sequential         | 5.6 M  | eval
# 2 | outputLayer         | Linear             | 10.2 K | train
# 3 | criterion           | CrossEntropyLoss   | 0      | train
# 4 | training_accuracy   | MulticlassAccuracy | 0      | train
# 5 | validation_accuracy | MulticlassAccuracy | 0      | train
# -------------------------------------------------------------------
# 3.4 M     Trainable params
# 3.3 M     Non-trainable params
# 6.6 M     Total params
# 26.541    Total estimated model params size (MB)
# 6         Modules in train mode
# 223       Modules in eval mode
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# Sanity Checking DataLoader 0: 100%|███████████████| 2/2 [00:00<00:00,  2.59it/s]/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/connectors/logger_connector/result.py:434: It is recommended to use `self.log('validation_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# Epoch 0: 100%|███████████████████████| 500/500 [02:31<00:00,  3.31it/s, v_num=0]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/125 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/125 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏                 | 1/125 [00:00<00:01, 74.07it/s]
# Validation DataLoader 0:   2%|▎                 | 2/125 [00:00<00:16,  7.33it/s]
# Validation DataLoader 0:   2%|▍                 | 3/125 [00:01<00:45,  2.65it/s]
# Validation DataLoader 0:   3%|▌                 | 4/125 [00:01<00:50,  2.40it/s]
# Validation DataLoader 0:   4%|▋                 | 5/125 [00:01<00:45,  2.63it/s]
# Validation DataLoader 0:   5%|▊                 | 6/125 [00:02<00:42,  2.82it/s]
# Validation DataLoader 0:   6%|█                 | 7/125 [00:02<00:40,  2.93it/s]
# Validation DataLoader 0:   6%|█▏                | 8/125 [00:02<00:39,  2.99it/s]
# Validation DataLoader 0:   7%|█▎                | 9/125 [00:02<00:37,  3.05it/s]
# Validation DataLoader 0:   8%|█▎               | 10/125 [00:03<00:37,  3.10it/s]
# Validation DataLoader 0:   9%|█▍               | 11/125 [00:03<00:36,  3.14it/s]
# Validation DataLoader 0:  10%|█▋               | 12/125 [00:03<00:35,  3.14it/s]
# Validation DataLoader 0:  10%|█▊               | 13/125 [00:04<00:35,  3.20it/s]
# Validation DataLoader 0:  11%|█▉               | 14/125 [00:04<00:34,  3.24it/s]
# Validation DataLoader 0:  12%|██               | 15/125 [00:04<00:33,  3.27it/s]
# Validation DataLoader 0:  13%|██▏              | 16/125 [00:04<00:32,  3.31it/s]
# Validation DataLoader 0:  14%|██▎              | 17/125 [00:05<00:32,  3.34it/s]
# Validation DataLoader 0:  14%|██▍              | 18/125 [00:05<00:32,  3.34it/s]
# Validation DataLoader 0:  15%|██▌              | 19/125 [00:05<00:31,  3.34it/s]
# Validation DataLoader 0:  16%|██▋              | 20/125 [00:05<00:31,  3.37it/s]
# Validation DataLoader 0:  17%|██▊              | 21/125 [00:06<00:30,  3.39it/s]
# Validation DataLoader 0:  18%|██▉              | 22/125 [00:06<00:30,  3.38it/s]
# Validation DataLoader 0:  18%|███▏             | 23/125 [00:06<00:30,  3.39it/s]
# Validation DataLoader 0:  19%|███▎             | 24/125 [00:07<00:29,  3.40it/s]
# Validation DataLoader 0:  20%|███▍             | 25/125 [00:07<00:29,  3.41it/s]
# Validation DataLoader 0:  21%|███▌             | 26/125 [00:07<00:28,  3.42it/s]
# Validation DataLoader 0:  22%|███▋             | 27/125 [00:07<00:28,  3.44it/s]
# Validation DataLoader 0:  22%|███▊             | 28/125 [00:08<00:28,  3.44it/s]
# Validation DataLoader 0:  23%|███▉             | 29/125 [00:08<00:27,  3.45it/s]
# Validation DataLoader 0:  24%|████             | 30/125 [00:08<00:27,  3.44it/s]
# Validation DataLoader 0:  25%|████▏            | 31/125 [00:08<00:27,  3.45it/s]
# Validation DataLoader 0:  26%|████▎            | 32/125 [00:09<00:27,  3.44it/s]
# Validation DataLoader 0:  26%|████▍            | 33/125 [00:09<00:26,  3.45it/s]
# Validation DataLoader 0:  27%|████▌            | 34/125 [00:09<00:26,  3.45it/s]
# Validation DataLoader 0:  28%|████▊            | 35/125 [00:10<00:26,  3.46it/s]
# Validation DataLoader 0:  29%|████▉            | 36/125 [00:10<00:25,  3.47it/s]
# Validation DataLoader 0:  30%|█████            | 37/125 [00:10<00:25,  3.48it/s]
# Validation DataLoader 0:  30%|█████▏           | 38/125 [00:10<00:25,  3.46it/s]
# Validation DataLoader 0:  31%|█████▎           | 39/125 [00:11<00:24,  3.45it/s]
# Validation DataLoader 0:  32%|█████▍           | 40/125 [00:11<00:24,  3.46it/s]
# Validation DataLoader 0:  33%|█████▌           | 41/125 [00:11<00:24,  3.46it/s]
# Validation DataLoader 0:  34%|█████▋           | 42/125 [00:12<00:23,  3.47it/s]
# Validation DataLoader 0:  34%|█████▊           | 43/125 [00:12<00:23,  3.48it/s]
# Validation DataLoader 0:  35%|█████▉           | 44/125 [00:12<00:23,  3.48it/s]
# Validation DataLoader 0:  36%|██████           | 45/125 [00:12<00:23,  3.47it/s]
# Validation DataLoader 0:  37%|██████▎          | 46/125 [00:13<00:22,  3.49it/s]
# Validation DataLoader 0:  38%|██████▍          | 47/125 [00:13<00:22,  3.50it/s]
# Validation DataLoader 0:  38%|██████▌          | 48/125 [00:13<00:21,  3.51it/s]
# Validation DataLoader 0:  39%|██████▋          | 49/125 [00:13<00:21,  3.52it/s]
# Validation DataLoader 0:  40%|██████▊          | 50/125 [00:14<00:21,  3.51it/s]
# Validation DataLoader 0:  41%|██████▉          | 51/125 [00:14<00:21,  3.51it/s]
# Validation DataLoader 0:  42%|███████          | 52/125 [00:14<00:20,  3.52it/s]
# Validation DataLoader 0:  42%|███████▏         | 53/125 [00:15<00:20,  3.53it/s]
# Validation DataLoader 0:  43%|███████▎         | 54/125 [00:15<00:20,  3.52it/s]
# Validation DataLoader 0:  44%|███████▍         | 55/125 [00:15<00:19,  3.53it/s]
# Validation DataLoader 0:  45%|███████▌         | 56/125 [00:15<00:19,  3.53it/s]
# Validation DataLoader 0:  46%|███████▊         | 57/125 [00:16<00:19,  3.54it/s]
# Validation DataLoader 0:  46%|███████▉         | 58/125 [00:16<00:18,  3.54it/s]
# Validation DataLoader 0:  47%|████████         | 59/125 [00:16<00:18,  3.54it/s]
# Validation DataLoader 0:  48%|████████▏        | 60/125 [00:16<00:18,  3.54it/s]
# Validation DataLoader 0:  49%|████████▎        | 61/125 [00:17<00:18,  3.55it/s]
# Validation DataLoader 0:  50%|████████▍        | 62/125 [00:17<00:17,  3.54it/s]
# Validation DataLoader 0:  50%|████████▌        | 63/125 [00:17<00:17,  3.55it/s]
# Validation DataLoader 0:  51%|████████▋        | 64/125 [00:18<00:17,  3.54it/s]
# Validation DataLoader 0:  52%|████████▊        | 65/125 [00:18<00:16,  3.54it/s]
# Validation DataLoader 0:  53%|████████▉        | 66/125 [00:18<00:16,  3.55it/s]
# Validation DataLoader 0:  54%|█████████        | 67/125 [00:18<00:16,  3.55it/s]
# Validation DataLoader 0:  54%|█████████▏       | 68/125 [00:19<00:16,  3.55it/s]
# Validation DataLoader 0:  55%|█████████▍       | 69/125 [00:19<00:15,  3.55it/s]
# Validation DataLoader 0:  56%|█████████▌       | 70/125 [00:19<00:15,  3.56it/s]
# Validation DataLoader 0:  57%|█████████▋       | 71/125 [00:19<00:15,  3.56it/s]
# Validation DataLoader 0:  58%|█████████▊       | 72/125 [00:20<00:14,  3.56it/s]
# Validation DataLoader 0:  58%|█████████▉       | 73/125 [00:20<00:14,  3.56it/s]
# Validation DataLoader 0:  59%|██████████       | 74/125 [00:20<00:14,  3.56it/s]
# Validation DataLoader 0:  60%|██████████▏      | 75/125 [00:21<00:14,  3.57it/s]
# Validation DataLoader 0:  61%|██████████▎      | 76/125 [00:21<00:13,  3.57it/s]
# Validation DataLoader 0:  62%|██████████▍      | 77/125 [00:21<00:13,  3.57it/s]
# Validation DataLoader 0:  62%|██████████▌      | 78/125 [00:21<00:13,  3.58it/s]
# Validation DataLoader 0:  63%|██████████▋      | 79/125 [00:22<00:12,  3.58it/s]
# Validation DataLoader 0:  64%|██████████▉      | 80/125 [00:22<00:12,  3.58it/s]
# Validation DataLoader 0:  65%|███████████      | 81/125 [00:22<00:12,  3.58it/s]
# Validation DataLoader 0:  66%|███████████▏     | 82/125 [00:22<00:11,  3.59it/s]
# Validation DataLoader 0:  66%|███████████▎     | 83/125 [00:23<00:11,  3.59it/s]
# Validation DataLoader 0:  67%|███████████▍     | 84/125 [00:23<00:11,  3.59it/s]
# Validation DataLoader 0:  68%|███████████▌     | 85/125 [00:23<00:11,  3.59it/s]
# Validation DataLoader 0:  69%|███████████▋     | 86/125 [00:23<00:10,  3.59it/s]
# Validation DataLoader 0:  70%|███████████▊     | 87/125 [00:24<00:10,  3.59it/s]
# Validation DataLoader 0:  70%|███████████▉     | 88/125 [00:24<00:10,  3.59it/s]
# Validation DataLoader 0:  71%|████████████     | 89/125 [00:24<00:10,  3.59it/s]
# Validation DataLoader 0:  72%|████████████▏    | 90/125 [00:25<00:09,  3.59it/s]
# Validation DataLoader 0:  73%|████████████▍    | 91/125 [00:25<00:09,  3.59it/s]
# Validation DataLoader 0:  74%|████████████▌    | 92/125 [00:25<00:09,  3.59it/s]
# Validation DataLoader 0:  74%|████████████▋    | 93/125 [00:25<00:08,  3.59it/s]
# Validation DataLoader 0:  75%|████████████▊    | 94/125 [00:26<00:08,  3.59it/s]
# Validation DataLoader 0:  76%|████████████▉    | 95/125 [00:26<00:08,  3.59it/s]
# Validation DataLoader 0:  77%|█████████████    | 96/125 [00:26<00:08,  3.59it/s]
# Validation DataLoader 0:  78%|█████████████▏   | 97/125 [00:26<00:07,  3.59it/s]
# Validation DataLoader 0:  78%|█████████████▎   | 98/125 [00:27<00:07,  3.60it/s]
# Validation DataLoader 0:  79%|█████████████▍   | 99/125 [00:27<00:07,  3.60it/s]
# Validation DataLoader 0:  80%|████████████▊   | 100/125 [00:27<00:06,  3.60it/s]
# Validation DataLoader 0:  81%|████████████▉   | 101/125 [00:28<00:06,  3.60it/s]
# Validation DataLoader 0:  82%|█████████████   | 102/125 [00:28<00:06,  3.60it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 103/125 [00:28<00:06,  3.60it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 104/125 [00:28<00:05,  3.60it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 105/125 [00:29<00:05,  3.60it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 106/125 [00:29<00:05,  3.61it/s]
# Validation DataLoader 0:  86%|█████████████▋  | 107/125 [00:29<00:04,  3.61it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 108/125 [00:29<00:04,  3.61it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 109/125 [00:30<00:04,  3.61it/s]
# Validation DataLoader 0:  88%|██████████████  | 110/125 [00:30<00:04,  3.61it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 111/125 [00:30<00:03,  3.62it/s]
# Validation DataLoader 0:  90%|██████████████▎ | 112/125 [00:30<00:03,  3.62it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 113/125 [00:31<00:03,  3.61it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 114/125 [00:31<00:03,  3.61it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 115/125 [00:31<00:02,  3.61it/s]
# Validation DataLoader 0:  93%|██████████████▊ | 116/125 [00:32<00:02,  3.54it/s]
# Validation DataLoader 0:  94%|██████████████▉ | 117/125 [00:33<00:02,  3.52it/s]
# Validation DataLoader 0:  94%|███████████████ | 118/125 [00:33<00:01,  3.52it/s]
# Validation DataLoader 0:  95%|███████████████▏| 119/125 [00:33<00:01,  3.53it/s]
# Validation DataLoader 0:  96%|███████████████▎| 120/125 [00:33<00:01,  3.53it/s]
# Validation DataLoader 0:  97%|███████████████▍| 121/125 [00:34<00:01,  3.53it/s]
# Validation DataLoader 0:  98%|███████████████▌| 122/125 [00:34<00:00,  3.53it/s]
# Validation DataLoader 0:  98%|███████████████▋| 123/125 [00:34<00:00,  3.53it/s]
# Validation DataLoader 0:  99%|███████████████▊| 124/125 [00:35<00:00,  3.53it/s]
# Validation DataLoader 0: 100%|████████████████| 125/125 [00:35<00:00,  3.53it/s]
# Epoch 0: 100%|█| 500/500 [03:06<00:00,  2.68it/s, v_num=0, validation_loss=0.954/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/connectors/logger_connector/result.py:434: It is recommended to use `self.log('training_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# Epoch 1: 100%|█| 500/500 [01:53<00:00,  4.40it/s, v_num=0, validation_loss=0.954
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/125 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/125 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏                 | 1/125 [00:00<00:01, 72.60it/s]
# Validation DataLoader 0:   2%|▎                 | 2/125 [00:00<00:13,  9.12it/s]
# Validation DataLoader 0:   2%|▍                 | 3/125 [00:00<00:16,  7.20it/s]
# Validation DataLoader 0:   3%|▌                 | 4/125 [00:00<00:18,  6.72it/s]
# Validation DataLoader 0:   4%|▋                 | 5/125 [00:00<00:18,  6.45it/s]
# Validation DataLoader 0:   5%|▊                 | 6/125 [00:00<00:18,  6.30it/s]
# Validation DataLoader 0:   6%|█                 | 7/125 [00:01<00:19,  6.01it/s]
# Validation DataLoader 0:   6%|█▏                | 8/125 [00:01<00:20,  5.77it/s]
# Validation DataLoader 0:   7%|█▎                | 9/125 [00:01<00:20,  5.65it/s]
# Validation DataLoader 0:   8%|█▎               | 10/125 [00:01<00:20,  5.58it/s]
# Validation DataLoader 0:   9%|█▍               | 11/125 [00:01<00:20,  5.51it/s]
# Validation DataLoader 0:  10%|█▋               | 12/125 [00:02<00:20,  5.45it/s]
# Validation DataLoader 0:  10%|█▊               | 13/125 [00:02<00:20,  5.43it/s]
# Validation DataLoader 0:  11%|█▉               | 14/125 [00:02<00:20,  5.41it/s]
# Validation DataLoader 0:  12%|██               | 15/125 [00:02<00:20,  5.39it/s]
# Validation DataLoader 0:  13%|██▏              | 16/125 [00:02<00:20,  5.38it/s]
# Validation DataLoader 0:  14%|██▎              | 17/125 [00:03<00:20,  5.36it/s]
# Validation DataLoader 0:  14%|██▍              | 18/125 [00:03<00:20,  5.32it/s]
# Validation DataLoader 0:  15%|██▌              | 19/125 [00:03<00:20,  5.29it/s]
# Validation DataLoader 0:  16%|██▋              | 20/125 [00:03<00:19,  5.28it/s]
# Validation DataLoader 0:  17%|██▊              | 21/125 [00:03<00:19,  5.26it/s]
# Validation DataLoader 0:  18%|██▉              | 22/125 [00:04<00:19,  5.25it/s]
# Validation DataLoader 0:  18%|███▏             | 23/125 [00:04<00:19,  5.25it/s]
# Validation DataLoader 0:  19%|███▎             | 24/125 [00:04<00:19,  5.23it/s]
# Validation DataLoader 0:  20%|███▍             | 25/125 [00:04<00:19,  5.24it/s]
# Validation DataLoader 0:  21%|███▌             | 26/125 [00:04<00:18,  5.23it/s]
# Validation DataLoader 0:  22%|███▋             | 27/125 [00:05<00:18,  5.22it/s]
# Validation DataLoader 0:  22%|███▊             | 28/125 [00:05<00:18,  5.23it/s]
# Validation DataLoader 0:  23%|███▉             | 29/125 [00:05<00:18,  5.22it/s]
# Validation DataLoader 0:  24%|████             | 30/125 [00:05<00:18,  5.21it/s]
# Validation DataLoader 0:  25%|████▏            | 31/125 [00:05<00:18,  5.20it/s]
# Validation DataLoader 0:  26%|████▎            | 32/125 [00:06<00:17,  5.18it/s]
# Validation DataLoader 0:  26%|████▍            | 33/125 [00:06<00:17,  5.18it/s]
# Validation DataLoader 0:  27%|████▌            | 34/125 [00:06<00:17,  5.16it/s]
# Validation DataLoader 0:  28%|████▊            | 35/125 [00:06<00:17,  5.13it/s]
# Validation DataLoader 0:  29%|████▉            | 36/125 [00:07<00:17,  5.14it/s]
# Validation DataLoader 0:  30%|█████            | 37/125 [00:07<00:17,  5.14it/s]
# Validation DataLoader 0:  30%|█████▏           | 38/125 [00:07<00:16,  5.14it/s]
# Validation DataLoader 0:  31%|█████▎           | 39/125 [00:07<00:16,  5.14it/s]
# Validation DataLoader 0:  32%|█████▍           | 40/125 [00:07<00:16,  5.14it/s]
# Validation DataLoader 0:  33%|█████▌           | 41/125 [00:07<00:16,  5.13it/s]
# Validation DataLoader 0:  34%|█████▋           | 42/125 [00:08<00:16,  5.13it/s]
# Validation DataLoader 0:  34%|█████▊           | 43/125 [00:08<00:15,  5.13it/s]
# Validation DataLoader 0:  35%|█████▉           | 44/125 [00:08<00:15,  5.12it/s]
# Validation DataLoader 0:  36%|██████           | 45/125 [00:08<00:15,  5.10it/s]
# Validation DataLoader 0:  37%|██████▎          | 46/125 [00:09<00:15,  5.10it/s]
# Validation DataLoader 0:  38%|██████▍          | 47/125 [00:09<00:15,  5.03it/s]
# Validation DataLoader 0:  38%|██████▌          | 48/125 [00:10<00:16,  4.79it/s]
# Validation DataLoader 0:  39%|██████▋          | 49/125 [00:10<00:16,  4.59it/s]
# Validation DataLoader 0:  40%|██████▊          | 50/125 [00:10<00:16,  4.59it/s]
# Validation DataLoader 0:  41%|██████▉          | 51/125 [00:11<00:16,  4.59it/s]
# Validation DataLoader 0:  42%|███████          | 52/125 [00:11<00:15,  4.61it/s]
# Validation DataLoader 0:  42%|███████▏         | 53/125 [00:11<00:15,  4.62it/s]
# Validation DataLoader 0:  43%|███████▎         | 54/125 [00:11<00:15,  4.62it/s]
# Validation DataLoader 0:  44%|███████▍         | 55/125 [00:11<00:15,  4.63it/s]
# Validation DataLoader 0:  45%|███████▌         | 56/125 [00:12<00:14,  4.63it/s]
# Validation DataLoader 0:  46%|███████▊         | 57/125 [00:12<00:14,  4.64it/s]
# Validation DataLoader 0:  46%|███████▉         | 58/125 [00:12<00:14,  4.65it/s]
# Validation DataLoader 0:  47%|████████         | 59/125 [00:12<00:14,  4.66it/s]
# Validation DataLoader 0:  48%|████████▏        | 60/125 [00:12<00:13,  4.66it/s]
# Validation DataLoader 0:  49%|████████▎        | 61/125 [00:13<00:13,  4.67it/s]
# Validation DataLoader 0:  50%|████████▍        | 62/125 [00:13<00:13,  4.66it/s]
# Validation DataLoader 0:  50%|████████▌        | 63/125 [00:13<00:13,  4.67it/s]
# Validation DataLoader 0:  51%|████████▋        | 64/125 [00:13<00:13,  4.68it/s]
# Validation DataLoader 0:  52%|████████▊        | 65/125 [00:13<00:12,  4.68it/s]
# Validation DataLoader 0:  53%|████████▉        | 66/125 [00:14<00:12,  4.69it/s]
# Validation DataLoader 0:  54%|█████████        | 67/125 [00:14<00:12,  4.69it/s]
# Validation DataLoader 0:  54%|█████████▏       | 68/125 [00:14<00:12,  4.70it/s]
# Validation DataLoader 0:  55%|█████████▍       | 69/125 [00:14<00:11,  4.71it/s]
# Validation DataLoader 0:  56%|█████████▌       | 70/125 [00:14<00:11,  4.72it/s]
# Validation DataLoader 0:  57%|█████████▋       | 71/125 [00:15<00:11,  4.72it/s]
# Validation DataLoader 0:  58%|█████████▊       | 72/125 [00:15<00:11,  4.73it/s]
# Validation DataLoader 0:  58%|█████████▉       | 73/125 [00:15<00:10,  4.73it/s]
# Validation DataLoader 0:  59%|██████████       | 74/125 [00:15<00:10,  4.74it/s]
# Validation DataLoader 0:  60%|██████████▏      | 75/125 [00:15<00:10,  4.74it/s]
# Validation DataLoader 0:  61%|██████████▎      | 76/125 [00:16<00:10,  4.74it/s]
# Validation DataLoader 0:  62%|██████████▍      | 77/125 [00:16<00:10,  4.75it/s]
# Validation DataLoader 0:  62%|██████████▌      | 78/125 [00:16<00:09,  4.75it/s]
# Validation DataLoader 0:  63%|██████████▋      | 79/125 [00:16<00:09,  4.76it/s]
# Validation DataLoader 0:  64%|██████████▉      | 80/125 [00:16<00:09,  4.76it/s]
# Validation DataLoader 0:  65%|███████████      | 81/125 [00:17<00:09,  4.76it/s]
# Validation DataLoader 0:  66%|███████████▏     | 82/125 [00:17<00:09,  4.77it/s]
# Validation DataLoader 0:  66%|███████████▎     | 83/125 [00:17<00:08,  4.77it/s]
# Validation DataLoader 0:  67%|███████████▍     | 84/125 [00:17<00:08,  4.78it/s]
# Validation DataLoader 0:  68%|███████████▌     | 85/125 [00:17<00:08,  4.78it/s]
# Validation DataLoader 0:  69%|███████████▋     | 86/125 [00:17<00:08,  4.79it/s]
# Validation DataLoader 0:  70%|███████████▊     | 87/125 [00:18<00:07,  4.79it/s]
# Validation DataLoader 0:  70%|███████████▉     | 88/125 [00:18<00:07,  4.79it/s]
# Validation DataLoader 0:  71%|████████████     | 89/125 [00:18<00:07,  4.80it/s]
# Validation DataLoader 0:  72%|████████████▏    | 90/125 [00:18<00:07,  4.79it/s]
# Validation DataLoader 0:  73%|████████████▍    | 91/125 [00:18<00:07,  4.79it/s]
# Validation DataLoader 0:  74%|████████████▌    | 92/125 [00:19<00:06,  4.80it/s]
# Validation DataLoader 0:  74%|████████████▋    | 93/125 [00:19<00:06,  4.80it/s]
# Validation DataLoader 0:  75%|████████████▊    | 94/125 [00:19<00:06,  4.81it/s]
# Validation DataLoader 0:  76%|████████████▉    | 95/125 [00:19<00:06,  4.81it/s]
# Validation DataLoader 0:  77%|█████████████    | 96/125 [00:19<00:06,  4.81it/s]
# Validation DataLoader 0:  78%|█████████████▏   | 97/125 [00:20<00:05,  4.82it/s]
# Validation DataLoader 0:  78%|█████████████▎   | 98/125 [00:20<00:05,  4.83it/s]
# Validation DataLoader 0:  79%|█████████████▍   | 99/125 [00:20<00:05,  4.83it/s]
# Validation DataLoader 0:  80%|████████████▊   | 100/125 [00:20<00:05,  4.83it/s]
# Validation DataLoader 0:  81%|████████████▉   | 101/125 [00:20<00:04,  4.83it/s]
# Validation DataLoader 0:  82%|█████████████   | 102/125 [00:21<00:04,  4.84it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 103/125 [00:21<00:04,  4.85it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 104/125 [00:21<00:04,  4.85it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 105/125 [00:21<00:04,  4.85it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 106/125 [00:21<00:03,  4.86it/s]
# Validation DataLoader 0:  86%|█████████████▋  | 107/125 [00:22<00:03,  4.86it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 108/125 [00:22<00:03,  4.87it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 109/125 [00:22<00:03,  4.87it/s]
# Validation DataLoader 0:  88%|██████████████  | 110/125 [00:22<00:03,  4.87it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 111/125 [00:22<00:02,  4.88it/s]
# Validation DataLoader 0:  90%|██████████████▎ | 112/125 [00:22<00:02,  4.87it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 113/125 [00:23<00:02,  4.88it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 114/125 [00:23<00:02,  4.88it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 115/125 [00:23<00:02,  4.89it/s]
# Validation DataLoader 0:  93%|██████████████▊ | 116/125 [00:23<00:01,  4.88it/s]
# Validation DataLoader 0:  94%|██████████████▉ | 117/125 [00:23<00:01,  4.88it/s]
# Validation DataLoader 0:  94%|███████████████ | 118/125 [00:24<00:01,  4.88it/s]
# Validation DataLoader 0:  95%|███████████████▏| 119/125 [00:24<00:01,  4.88it/s]
# Validation DataLoader 0:  96%|███████████████▎| 120/125 [00:24<00:01,  4.88it/s]
# Validation DataLoader 0:  97%|███████████████▍| 121/125 [00:24<00:00,  4.89it/s]
# Validation DataLoader 0:  98%|███████████████▌| 122/125 [00:24<00:00,  4.89it/s]
# Validation DataLoader 0:  98%|███████████████▋| 123/125 [00:25<00:00,  4.88it/s]
# Validation DataLoader 0:  99%|███████████████▊| 124/125 [00:25<00:00,  4.89it/s]
# Validation DataLoader 0: 100%|████████████████| 125/125 [00:25<00:00,  4.89it/s]
# Epoch 2: 100%|█| 500/500 [01:53<00:00,  4.39it/s, v_num=0, validation_loss=0.918
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/125 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/125 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏                 | 1/125 [00:00<00:01, 69.91it/s]
# Validation DataLoader 0:   2%|▎                 | 2/125 [00:00<00:13,  9.22it/s]
# Validation DataLoader 0:   2%|▍                 | 3/125 [00:00<00:16,  7.27it/s]
# Validation DataLoader 0:   3%|▌                 | 4/125 [00:00<00:17,  6.79it/s]
# Validation DataLoader 0:   4%|▋                 | 5/125 [00:00<00:18,  6.54it/s]
# Validation DataLoader 0:   5%|▊                 | 6/125 [00:00<00:18,  6.39it/s]
# Validation DataLoader 0:   6%|█                 | 7/125 [00:01<00:19,  6.21it/s]
# Validation DataLoader 0:   6%|█▏                | 8/125 [00:01<00:19,  6.01it/s]
# Validation DataLoader 0:   7%|█▎                | 9/125 [00:01<00:19,  5.89it/s]
# Validation DataLoader 0:   8%|█▎               | 10/125 [00:01<00:19,  5.81it/s]
# Validation DataLoader 0:   9%|█▍               | 11/125 [00:01<00:19,  5.71it/s]
# Validation DataLoader 0:  10%|█▋               | 12/125 [00:02<00:19,  5.66it/s]
# Validation DataLoader 0:  10%|█▊               | 13/125 [00:02<00:19,  5.64it/s]
# Validation DataLoader 0:  11%|█▉               | 14/125 [00:02<00:19,  5.60it/s]
# Validation DataLoader 0:  12%|██               | 15/125 [00:02<00:19,  5.56it/s]
# Validation DataLoader 0:  13%|██▏              | 16/125 [00:02<00:19,  5.54it/s]
# Validation DataLoader 0:  14%|██▎              | 17/125 [00:03<00:19,  5.51it/s]
# Validation DataLoader 0:  14%|██▍              | 18/125 [00:03<00:19,  5.47it/s]
# Validation DataLoader 0:  15%|██▌              | 19/125 [00:03<00:19,  5.42it/s]
# Validation DataLoader 0:  16%|██▋              | 20/125 [00:03<00:19,  5.41it/s]
# Validation DataLoader 0:  17%|██▊              | 21/125 [00:03<00:19,  5.40it/s]
# Validation DataLoader 0:  18%|██▉              | 22/125 [00:04<00:19,  5.38it/s]
# Validation DataLoader 0:  18%|███▏             | 23/125 [00:04<00:18,  5.38it/s]
# Validation DataLoader 0:  19%|███▎             | 24/125 [00:04<00:18,  5.35it/s]
# Validation DataLoader 0:  20%|███▍             | 25/125 [00:04<00:18,  5.34it/s]
# Validation DataLoader 0:  21%|███▌             | 26/125 [00:04<00:18,  5.34it/s]
# Validation DataLoader 0:  22%|███▋             | 27/125 [00:05<00:18,  5.32it/s]
# Validation DataLoader 0:  22%|███▊             | 28/125 [00:05<00:18,  5.34it/s]
# Validation DataLoader 0:  23%|███▉             | 29/125 [00:05<00:17,  5.33it/s]
# Validation DataLoader 0:  24%|████             | 30/125 [00:05<00:17,  5.32it/s]
# Validation DataLoader 0:  25%|████▏            | 31/125 [00:05<00:17,  5.31it/s]
# Validation DataLoader 0:  26%|████▎            | 32/125 [00:06<00:17,  5.30it/s]
# Validation DataLoader 0:  26%|████▍            | 33/125 [00:06<00:17,  5.30it/s]
# Validation DataLoader 0:  27%|████▌            | 34/125 [00:06<00:17,  5.28it/s]
# Validation DataLoader 0:  28%|████▊            | 35/125 [00:06<00:17,  5.27it/s]
# Validation DataLoader 0:  29%|████▉            | 36/125 [00:06<00:16,  5.27it/s]
# Validation DataLoader 0:  30%|█████            | 37/125 [00:07<00:16,  5.28it/s]
# Validation DataLoader 0:  30%|█████▏           | 38/125 [00:07<00:16,  5.27it/s]
# Validation DataLoader 0:  31%|█████▎           | 39/125 [00:07<00:16,  5.27it/s]
# Validation DataLoader 0:  32%|█████▍           | 40/125 [00:07<00:16,  5.27it/s]
# Validation DataLoader 0:  33%|█████▌           | 41/125 [00:07<00:15,  5.27it/s]
# Validation DataLoader 0:  34%|█████▋           | 42/125 [00:07<00:15,  5.26it/s]
# Validation DataLoader 0:  34%|█████▊           | 43/125 [00:08<00:15,  5.26it/s]
# Validation DataLoader 0:  35%|█████▉           | 44/125 [00:08<00:15,  5.25it/s]
# Validation DataLoader 0:  36%|██████           | 45/125 [00:08<00:15,  5.24it/s]
# Validation DataLoader 0:  37%|██████▎          | 46/125 [00:08<00:15,  5.22it/s]
# Validation DataLoader 0:  38%|██████▍          | 47/125 [00:08<00:14,  5.23it/s]
# Validation DataLoader 0:  38%|██████▌          | 48/125 [00:09<00:14,  5.23it/s]
# Validation DataLoader 0:  39%|██████▋          | 49/125 [00:09<00:14,  5.24it/s]
# Validation DataLoader 0:  40%|██████▊          | 50/125 [00:09<00:14,  5.22it/s]
# Validation DataLoader 0:  41%|██████▉          | 51/125 [00:09<00:14,  5.20it/s]
# Validation DataLoader 0:  42%|███████          | 52/125 [00:09<00:14,  5.21it/s]
# Validation DataLoader 0:  42%|███████▏         | 53/125 [00:10<00:13,  5.21it/s]
# Validation DataLoader 0:  43%|███████▎         | 54/125 [00:10<00:13,  5.20it/s]
# Validation DataLoader 0:  44%|███████▍         | 55/125 [00:10<00:13,  5.20it/s]
# Validation DataLoader 0:  45%|███████▌         | 56/125 [00:10<00:13,  5.19it/s]
# Validation DataLoader 0:  46%|███████▊         | 57/125 [00:10<00:13,  5.19it/s]
# Validation DataLoader 0:  46%|███████▉         | 58/125 [00:11<00:12,  5.19it/s]
# Validation DataLoader 0:  47%|████████         | 59/125 [00:11<00:12,  5.19it/s]
# Validation DataLoader 0:  48%|████████▏        | 60/125 [00:11<00:12,  5.18it/s]
# Validation DataLoader 0:  49%|████████▎        | 61/125 [00:11<00:12,  5.19it/s]
# Validation DataLoader 0:  50%|████████▍        | 62/125 [00:11<00:12,  5.18it/s]
# Validation DataLoader 0:  50%|████████▌        | 63/125 [00:12<00:11,  5.17it/s]
# Validation DataLoader 0:  51%|████████▋        | 64/125 [00:12<00:11,  5.18it/s]
# Validation DataLoader 0:  52%|████████▊        | 65/125 [00:12<00:11,  5.18it/s]
# Validation DataLoader 0:  53%|████████▉        | 66/125 [00:12<00:11,  5.17it/s]
# Validation DataLoader 0:  54%|█████████        | 67/125 [00:12<00:11,  5.17it/s]
# Validation DataLoader 0:  54%|█████████▏       | 68/125 [00:13<00:11,  5.18it/s]
# Validation DataLoader 0:  55%|█████████▍       | 69/125 [00:13<00:10,  5.18it/s]
# Validation DataLoader 0:  56%|█████████▌       | 70/125 [00:13<00:10,  5.18it/s]
# Validation DataLoader 0:  57%|█████████▋       | 71/125 [00:13<00:10,  5.18it/s]
# Validation DataLoader 0:  58%|█████████▊       | 72/125 [00:13<00:10,  5.18it/s]
# Validation DataLoader 0:  58%|█████████▉       | 73/125 [00:14<00:10,  5.18it/s]
# Validation DataLoader 0:  59%|██████████       | 74/125 [00:14<00:09,  5.18it/s]
# Validation DataLoader 0:  60%|██████████▏      | 75/125 [00:14<00:09,  5.18it/s]
# Validation DataLoader 0:  61%|██████████▎      | 76/125 [00:14<00:09,  5.18it/s]
# Validation DataLoader 0:  62%|██████████▍      | 77/125 [00:14<00:09,  5.18it/s]
# Validation DataLoader 0:  62%|██████████▌      | 78/125 [00:15<00:09,  5.17it/s]
# Validation DataLoader 0:  63%|██████████▋      | 79/125 [00:15<00:08,  5.17it/s]
# Validation DataLoader 0:  64%|██████████▉      | 80/125 [00:15<00:08,  5.17it/s]
# Validation DataLoader 0:  65%|███████████      | 81/125 [00:15<00:08,  5.17it/s]
# Validation DataLoader 0:  66%|███████████▏     | 82/125 [00:15<00:08,  5.18it/s]
# Validation DataLoader 0:  66%|███████████▎     | 83/125 [00:16<00:08,  5.18it/s]
# Validation DataLoader 0:  67%|███████████▍     | 84/125 [00:16<00:07,  5.18it/s]
# Validation DataLoader 0:  68%|███████████▌     | 85/125 [00:16<00:07,  5.18it/s]
# Validation DataLoader 0:  69%|███████████▋     | 86/125 [00:16<00:07,  5.18it/s]
# Validation DataLoader 0:  70%|███████████▊     | 87/125 [00:16<00:07,  5.17it/s]
# Validation DataLoader 0:  70%|███████████▉     | 88/125 [00:17<00:07,  5.16it/s]
# Validation DataLoader 0:  71%|████████████     | 89/125 [00:17<00:06,  5.17it/s]
# Validation DataLoader 0:  72%|████████████▏    | 90/125 [00:17<00:06,  5.16it/s]
# Validation DataLoader 0:  73%|████████████▍    | 91/125 [00:17<00:06,  5.16it/s]
# Validation DataLoader 0:  74%|████████████▌    | 92/125 [00:17<00:06,  5.16it/s]
# Validation DataLoader 0:  74%|████████████▋    | 93/125 [00:18<00:06,  5.16it/s]
# Validation DataLoader 0:  75%|████████████▊    | 94/125 [00:18<00:06,  5.16it/s]
# Validation DataLoader 0:  76%|████████████▉    | 95/125 [00:18<00:05,  5.15it/s]
# Validation DataLoader 0:  77%|█████████████    | 96/125 [00:18<00:05,  5.15it/s]
# Validation DataLoader 0:  78%|█████████████▏   | 97/125 [00:18<00:05,  5.14it/s]
# Validation DataLoader 0:  78%|█████████████▎   | 98/125 [00:19<00:05,  5.14it/s]
# Validation DataLoader 0:  79%|█████████████▍   | 99/125 [00:19<00:05,  5.14it/s]
# Validation DataLoader 0:  80%|████████████▊   | 100/125 [00:19<00:04,  5.14it/s]
# Validation DataLoader 0:  81%|████████████▉   | 101/125 [00:19<00:04,  5.14it/s]
# Validation DataLoader 0:  82%|█████████████   | 102/125 [00:19<00:04,  5.14it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 103/125 [00:20<00:04,  5.15it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 104/125 [00:20<00:04,  5.15it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 105/125 [00:20<00:03,  5.15it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 106/125 [00:20<00:03,  5.15it/s]
# Validation DataLoader 0:  86%|█████████████▋  | 107/125 [00:20<00:03,  5.15it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 108/125 [00:20<00:03,  5.15it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 109/125 [00:21<00:03,  5.15it/s]
# Validation DataLoader 0:  88%|██████████████  | 110/125 [00:21<00:02,  5.15it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 111/125 [00:21<00:02,  5.15it/s]
# Validation DataLoader 0:  90%|██████████████▎ | 112/125 [00:21<00:02,  5.15it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 113/125 [00:21<00:02,  5.15it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 114/125 [00:22<00:02,  5.15it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 115/125 [00:22<00:01,  5.15it/s]
# Validation DataLoader 0:  93%|██████████████▊ | 116/125 [00:22<00:01,  5.15it/s]
# Validation DataLoader 0:  94%|██████████████▉ | 117/125 [00:22<00:01,  5.15it/s]
# Validation DataLoader 0:  94%|███████████████ | 118/125 [00:22<00:01,  5.15it/s]
# Validation DataLoader 0:  95%|███████████████▏| 119/125 [00:23<00:01,  5.15it/s]
# Validation DataLoader 0:  96%|███████████████▎| 120/125 [00:23<00:00,  5.15it/s]
# Validation DataLoader 0:  97%|███████████████▍| 121/125 [00:23<00:00,  5.15it/s]
# Validation DataLoader 0:  98%|███████████████▌| 122/125 [00:23<00:00,  5.15it/s]
# Validation DataLoader 0:  98%|███████████████▋| 123/125 [00:23<00:00,  5.15it/s]
# Validation DataLoader 0:  99%|███████████████▊| 124/125 [00:24<00:00,  5.15it/s]
# Validation DataLoader 0: 100%|████████████████| 125/125 [00:24<00:00,  5.14it/s]
# Epoch 3: 100%|█| 500/500 [01:53<00:00,  4.41it/s, v_num=0, validation_loss=0.862
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/125 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/125 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏                 | 1/125 [00:00<00:01, 72.08it/s]
# Validation DataLoader 0:   2%|▎                 | 2/125 [00:00<00:13,  9.34it/s]
# Validation DataLoader 0:   2%|▍                 | 3/125 [00:00<00:17,  7.05it/s]
# Validation DataLoader 0:   3%|▌                 | 4/125 [00:00<00:20,  6.02it/s]
# Validation DataLoader 0:   4%|▋                 | 5/125 [00:00<00:20,  5.94it/s]
# Validation DataLoader 0:   5%|▊                 | 6/125 [00:01<00:20,  5.91it/s]
# Validation DataLoader 0:   6%|█                 | 7/125 [00:01<00:20,  5.80it/s]
# Validation DataLoader 0:   6%|█▏                | 8/125 [00:01<00:20,  5.65it/s]
# Validation DataLoader 0:   7%|█▎                | 9/125 [00:01<00:20,  5.57it/s]
# Validation DataLoader 0:   8%|█▎               | 10/125 [00:01<00:20,  5.53it/s]
# Validation DataLoader 0:   9%|█▍               | 11/125 [00:02<00:20,  5.46it/s]
# Validation DataLoader 0:  10%|█▋               | 12/125 [00:02<00:20,  5.43it/s]
# Validation DataLoader 0:  10%|█▊               | 13/125 [00:02<00:20,  5.42it/s]
# Validation DataLoader 0:  11%|█▉               | 14/125 [00:02<00:20,  5.40it/s]
# Validation DataLoader 0:  12%|██               | 15/125 [00:02<00:20,  5.39it/s]
# Validation DataLoader 0:  13%|██▏              | 16/125 [00:02<00:20,  5.39it/s]
# Validation DataLoader 0:  14%|██▎              | 17/125 [00:03<00:20,  5.37it/s]
# Validation DataLoader 0:  14%|██▍              | 18/125 [00:03<00:20,  5.34it/s]
# Validation DataLoader 0:  15%|██▌              | 19/125 [00:03<00:20,  5.29it/s]
# Validation DataLoader 0:  16%|██▋              | 20/125 [00:03<00:19,  5.29it/s]
# Validation DataLoader 0:  17%|██▊              | 21/125 [00:03<00:19,  5.28it/s]
# Validation DataLoader 0:  18%|██▉              | 22/125 [00:04<00:19,  5.28it/s]
# Validation DataLoader 0:  18%|███▏             | 23/125 [00:04<00:19,  5.29it/s]
# Validation DataLoader 0:  19%|███▎             | 24/125 [00:04<00:19,  5.27it/s]
# Validation DataLoader 0:  20%|███▍             | 25/125 [00:04<00:18,  5.28it/s]
# Validation DataLoader 0:  21%|███▌             | 26/125 [00:04<00:18,  5.28it/s]
# Validation DataLoader 0:  22%|███▋             | 27/125 [00:05<00:18,  5.27it/s]
# Validation DataLoader 0:  22%|███▊             | 28/125 [00:05<00:18,  5.30it/s]
# Validation DataLoader 0:  23%|███▉             | 29/125 [00:05<00:18,  5.29it/s]
# Validation DataLoader 0:  24%|████             | 30/125 [00:05<00:17,  5.28it/s]
# Validation DataLoader 0:  25%|████▏            | 31/125 [00:05<00:17,  5.27it/s]
# Validation DataLoader 0:  26%|████▎            | 32/125 [00:06<00:17,  5.26it/s]
# Validation DataLoader 0:  26%|████▍            | 33/125 [00:06<00:17,  5.26it/s]
# Validation DataLoader 0:  27%|████▌            | 34/125 [00:06<00:17,  5.24it/s]
# Validation DataLoader 0:  28%|████▊            | 35/125 [00:06<00:17,  5.23it/s]
# Validation DataLoader 0:  29%|████▉            | 36/125 [00:06<00:17,  5.23it/s]
# Validation DataLoader 0:  30%|█████            | 37/125 [00:07<00:16,  5.23it/s]
# Validation DataLoader 0:  30%|█████▏           | 38/125 [00:07<00:16,  5.23it/s]
# Validation DataLoader 0:  31%|█████▎           | 39/125 [00:07<00:16,  5.22it/s]
# Validation DataLoader 0:  32%|█████▍           | 40/125 [00:07<00:16,  5.23it/s]
# Validation DataLoader 0:  33%|█████▌           | 41/125 [00:07<00:16,  5.23it/s]
# Validation DataLoader 0:  34%|█████▋           | 42/125 [00:08<00:15,  5.22it/s]
# Validation DataLoader 0:  34%|█████▊           | 43/125 [00:08<00:15,  5.21it/s]
# Validation DataLoader 0:  35%|█████▉           | 44/125 [00:08<00:15,  5.21it/s]
# Validation DataLoader 0:  36%|██████           | 45/125 [00:08<00:15,  5.22it/s]
# Validation DataLoader 0:  37%|██████▎          | 46/125 [00:08<00:15,  5.22it/s]
# Validation DataLoader 0:  38%|██████▍          | 47/125 [00:09<00:14,  5.22it/s]
# Validation DataLoader 0:  38%|██████▌          | 48/125 [00:09<00:14,  5.22it/s]
# Validation DataLoader 0:  39%|██████▋          | 49/125 [00:09<00:14,  5.22it/s]
# Validation DataLoader 0:  40%|██████▊          | 50/125 [00:09<00:14,  5.20it/s]
# Validation DataLoader 0:  41%|██████▉          | 51/125 [00:09<00:14,  5.19it/s]
# Validation DataLoader 0:  42%|███████          | 52/125 [00:10<00:14,  5.19it/s]
# Validation DataLoader 0:  42%|███████▏         | 53/125 [00:10<00:13,  5.20it/s]
# Validation DataLoader 0:  43%|███████▎         | 54/125 [00:10<00:13,  5.18it/s]
# Validation DataLoader 0:  44%|███████▍         | 55/125 [00:10<00:13,  5.16it/s]
# Validation DataLoader 0:  45%|███████▌         | 56/125 [00:10<00:13,  5.16it/s]
# Validation DataLoader 0:  46%|███████▊         | 57/125 [00:11<00:13,  5.16it/s]
# Validation DataLoader 0:  46%|███████▉         | 58/125 [00:11<00:13,  5.15it/s]
# Validation DataLoader 0:  47%|████████         | 59/125 [00:11<00:12,  5.15it/s]
# Validation DataLoader 0:  48%|████████▏        | 60/125 [00:11<00:12,  5.15it/s]
# Validation DataLoader 0:  49%|████████▎        | 61/125 [00:11<00:12,  5.15it/s]
# Validation DataLoader 0:  50%|████████▍        | 62/125 [00:12<00:12,  5.14it/s]
# Validation DataLoader 0:  50%|████████▌        | 63/125 [00:12<00:12,  5.13it/s]
# Validation DataLoader 0:  51%|████████▋        | 64/125 [00:12<00:11,  5.14it/s]
# Validation DataLoader 0:  52%|████████▊        | 65/125 [00:12<00:11,  5.13it/s]
# Validation DataLoader 0:  53%|████████▉        | 66/125 [00:12<00:11,  5.13it/s]
# Validation DataLoader 0:  54%|█████████        | 67/125 [00:13<00:11,  5.13it/s]
# Validation DataLoader 0:  54%|█████████▏       | 68/125 [00:13<00:11,  5.14it/s]
# Validation DataLoader 0:  55%|█████████▍       | 69/125 [00:13<00:10,  5.14it/s]
# Validation DataLoader 0:  56%|█████████▌       | 70/125 [00:13<00:10,  5.14it/s]
# Validation DataLoader 0:  57%|█████████▋       | 71/125 [00:13<00:10,  5.14it/s]
# Validation DataLoader 0:  58%|█████████▊       | 72/125 [00:14<00:10,  5.13it/s]
# Validation DataLoader 0:  58%|█████████▉       | 73/125 [00:14<00:10,  5.13it/s]
# Validation DataLoader 0:  59%|██████████       | 74/125 [00:14<00:09,  5.14it/s]
# Validation DataLoader 0:  60%|██████████▏      | 75/125 [00:14<00:09,  5.14it/s]
# Validation DataLoader 0:  61%|██████████▎      | 76/125 [00:14<00:09,  5.14it/s]
# Validation DataLoader 0:  62%|██████████▍      | 77/125 [00:14<00:09,  5.14it/s]
# Validation DataLoader 0:  62%|██████████▌      | 78/125 [00:15<00:09,  5.14it/s]
# Validation DataLoader 0:  63%|██████████▋      | 79/125 [00:15<00:08,  5.14it/s]
# Validation DataLoader 0:  64%|██████████▉      | 80/125 [00:15<00:08,  5.14it/s]
# Validation DataLoader 0:  65%|███████████      | 81/125 [00:15<00:08,  5.14it/s]
# Validation DataLoader 0:  66%|███████████▏     | 82/125 [00:15<00:08,  5.14it/s]
# Validation DataLoader 0:  66%|███████████▎     | 83/125 [00:16<00:08,  5.14it/s]
# Validation DataLoader 0:  67%|███████████▍     | 84/125 [00:16<00:08,  5.03it/s]
# Validation DataLoader 0:  68%|███████████▌     | 85/125 [00:17<00:08,  4.85it/s]
# Validation DataLoader 0:  69%|███████████▋     | 86/125 [00:17<00:08,  4.83it/s]
# Validation DataLoader 0:  70%|███████████▊     | 87/125 [00:18<00:07,  4.83it/s]
# Validation DataLoader 0:  70%|███████████▉     | 88/125 [00:18<00:07,  4.83it/s]
# Validation DataLoader 0:  71%|████████████     | 89/125 [00:18<00:07,  4.83it/s]
# Validation DataLoader 0:  72%|████████████▏    | 90/125 [00:18<00:07,  4.83it/s]
# Validation DataLoader 0:  73%|████████████▍    | 91/125 [00:18<00:07,  4.84it/s]
# Validation DataLoader 0:  74%|████████████▌    | 92/125 [00:19<00:06,  4.84it/s]
# Validation DataLoader 0:  74%|████████████▋    | 93/125 [00:19<00:06,  4.84it/s]
# Validation DataLoader 0:  75%|████████████▊    | 94/125 [00:19<00:06,  4.84it/s]
# Validation DataLoader 0:  76%|████████████▉    | 95/125 [00:19<00:06,  4.84it/s]
# Validation DataLoader 0:  77%|█████████████    | 96/125 [00:19<00:05,  4.85it/s]
# Validation DataLoader 0:  78%|█████████████▏   | 97/125 [00:19<00:05,  4.85it/s]
# Validation DataLoader 0:  78%|█████████████▎   | 98/125 [00:20<00:05,  4.86it/s]
# Validation DataLoader 0:  79%|█████████████▍   | 99/125 [00:20<00:05,  4.86it/s]
# Validation DataLoader 0:  80%|████████████▊   | 100/125 [00:20<00:05,  4.85it/s]
# Validation DataLoader 0:  81%|████████████▉   | 101/125 [00:20<00:04,  4.85it/s]
# Validation DataLoader 0:  82%|█████████████   | 102/125 [00:20<00:04,  4.86it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 103/125 [00:21<00:04,  4.86it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 104/125 [00:21<00:04,  4.87it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 105/125 [00:21<00:04,  4.86it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 106/125 [00:21<00:03,  4.87it/s]
# Validation DataLoader 0:  86%|█████████████▋  | 107/125 [00:21<00:03,  4.87it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 108/125 [00:22<00:03,  4.88it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 109/125 [00:22<00:03,  4.88it/s]
# Validation DataLoader 0:  88%|██████████████  | 110/125 [00:22<00:03,  4.88it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 111/125 [00:22<00:02,  4.88it/s]
# Validation DataLoader 0:  90%|██████████████▎ | 112/125 [00:22<00:02,  4.88it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 113/125 [00:23<00:02,  4.89it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 114/125 [00:23<00:02,  4.89it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 115/125 [00:23<00:02,  4.89it/s]
# Validation DataLoader 0:  93%|██████████████▊ | 116/125 [00:23<00:01,  4.89it/s]
# Validation DataLoader 0:  94%|██████████████▉ | 117/125 [00:23<00:01,  4.89it/s]
# Validation DataLoader 0:  94%|███████████████ | 118/125 [00:24<00:01,  4.89it/s]
# Validation DataLoader 0:  95%|███████████████▏| 119/125 [00:24<00:01,  4.90it/s]
# Validation DataLoader 0:  96%|███████████████▎| 120/125 [00:24<00:01,  4.91it/s]
# Validation DataLoader 0:  97%|███████████████▍| 121/125 [00:24<00:00,  4.91it/s]
# Validation DataLoader 0:  98%|███████████████▌| 122/125 [00:24<00:00,  4.91it/s]
# Validation DataLoader 0:  98%|███████████████▋| 123/125 [00:25<00:00,  4.90it/s]
# Validation DataLoader 0:  99%|███████████████▊| 124/125 [00:25<00:00,  4.91it/s]
# Validation DataLoader 0: 100%|████████████████| 125/125 [00:25<00:00,  4.91it/s]
# Epoch 4: 100%|█| 500/500 [01:53<00:00,  4.42it/s, v_num=0, validation_loss=0.888
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/125 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/125 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏                 | 1/125 [00:00<00:01, 74.94it/s]
# Validation DataLoader 0:   2%|▎                 | 2/125 [00:00<00:14,  8.69it/s]
# Validation DataLoader 0:   2%|▍                 | 3/125 [00:00<00:17,  7.10it/s]
# Validation DataLoader 0:   3%|▌                 | 4/125 [00:00<00:18,  6.66it/s]
# Validation DataLoader 0:   4%|▋                 | 5/125 [00:00<00:18,  6.40it/s]
# Validation DataLoader 0:   5%|▊                 | 6/125 [00:00<00:19,  6.22it/s]
# Validation DataLoader 0:   6%|█                 | 7/125 [00:01<00:19,  6.01it/s]
# Validation DataLoader 0:   6%|█▏                | 8/125 [00:01<00:20,  5.79it/s]
# Validation DataLoader 0:   7%|█▎                | 9/125 [00:01<00:20,  5.65it/s]
# Validation DataLoader 0:   8%|█▎               | 10/125 [00:01<00:21,  5.44it/s]
# Validation DataLoader 0:   9%|█▍               | 11/125 [00:02<00:21,  5.38it/s]
# Validation DataLoader 0:  10%|█▋               | 12/125 [00:02<00:21,  5.34it/s]
# Validation DataLoader 0:  10%|█▊               | 13/125 [00:02<00:21,  5.31it/s]
# Validation DataLoader 0:  11%|█▉               | 14/125 [00:02<00:21,  5.24it/s]
# Validation DataLoader 0:  12%|██               | 15/125 [00:02<00:21,  5.23it/s]
# Validation DataLoader 0:  13%|██▏              | 16/125 [00:03<00:21,  5.01it/s]
# Validation DataLoader 0:  14%|██▎              | 17/125 [00:03<00:21,  5.00it/s]
# Validation DataLoader 0:  14%|██▍              | 18/125 [00:03<00:21,  4.99it/s]
# Validation DataLoader 0:  15%|██▌              | 19/125 [00:03<00:21,  4.95it/s]
# ...
# Validation DataLoader 0:  53%|████████▉        | 66/125 [00:12<00:11,  5.09it/s]
# Validation DataLoader 0:  54%|█████████        | 67/125 [00:13<00:11,  5.09it/s]
# Validation DataLoader 0:  54%|█████████▏       | 68/125 [00:13<00:11,  5.08it/s]
# Validation DataLoader 0:  55%|█████████▍       | 69/125 [00:13<00:11,  5.08it/s]
# Validation DataLoader 0:  56%|█████████▌       | 70/125 [00:13<00:10,  5.08it/s]
# Validation DataLoader 0:  57%|█████████▋       | 71/125 [00:13<00:10,  5.08it/s]
# Validation DataLoader 0:  58%|█████████▊       | 72/125 [00:14<00:10,  5.08it/s]
# Validation DataLoader 0:  58%|█████████▉       | 73/125 [00:14<00:10,  5.07it/s]
# Validation DataLoader 0:  59%|██████████       | 74/125 [00:14<00:10,  5.07it/s]
# Validation DataLoader 0:  60%|██████████▏      | 75/125 [00:14<00:09,  5.08it/s]
# Validation DataLoader 0:  61%|██████████▎      | 76/125 [00:14<00:09,  5.08it/s]
# Validation DataLoader 0:  62%|██████████▍      | 77/125 [00:15<00:09,  5.07it/s]
# Validation DataLoader 0:  62%|██████████▌      | 78/125 [00:15<00:09,  5.07it/s]
# Validation DataLoader 0:  63%|██████████▋      | 79/125 [00:15<00:09,  5.07it/s]
# Validation DataLoader 0:  64%|██████████▉      | 80/125 [00:15<00:08,  5.07it/s]
# Validation DataLoader 0:  65%|███████████      | 81/125 [00:15<00:08,  5.07it/s]
# Validation DataLoader 0:  66%|███████████▏     | 82/125 [00:16<00:08,  5.08it/s]
# Validation DataLoader 0:  66%|███████████▎     | 83/125 [00:16<00:08,  5.08it/s]
# Validation DataLoader 0:  67%|███████████▍     | 84/125 [00:16<00:08,  5.08it/s]
# Validation DataLoader 0:  68%|███████████▌     | 85/125 [00:16<00:07,  5.08it/s]
# Validation DataLoader 0:  69%|███████████▋     | 86/125 [00:16<00:07,  5.07it/s]
# Validation DataLoader 0:  70%|███████████▊     | 87/125 [00:17<00:07,  5.07it/s]
# Validation DataLoader 0:  70%|███████████▉     | 88/125 [00:17<00:07,  5.05it/s]
# Validation DataLoader 0:  71%|████████████     | 89/125 [00:17<00:07,  5.06it/s]
# Validation DataLoader 0:  72%|████████████▏    | 90/125 [00:17<00:06,  5.06it/s]
# Validation DataLoader 0:  73%|████████████▍    | 91/125 [00:17<00:06,  5.06it/s]
# Validation DataLoader 0:  74%|████████████▌    | 92/125 [00:18<00:06,  5.06it/s]
# Validation DataLoader 0:  74%|████████████▋    | 93/125 [00:18<00:06,  5.06it/s]
# Validation DataLoader 0:  75%|████████████▊    | 94/125 [00:18<00:06,  5.07it/s]
# Validation DataLoader 0:  76%|████████████▉    | 95/125 [00:18<00:05,  5.05it/s]
# Validation DataLoader 0:  77%|█████████████    | 96/125 [00:19<00:05,  4.93it/s]
# Validation DataLoader 0:  78%|█████████████▏   | 97/125 [00:20<00:05,  4.80it/s]
# Validation DataLoader 0:  78%|█████████████▎   | 98/125 [00:20<00:05,  4.80it/s]
# Validation DataLoader 0:  79%|█████████████▍   | 99/125 [00:20<00:05,  4.81it/s]
# Validation DataLoader 0:  80%|████████████▊   | 100/125 [00:20<00:05,  4.81it/s]
# Validation DataLoader 0:  81%|████████████▉   | 101/125 [00:20<00:04,  4.81it/s]
# Validation DataLoader 0:  82%|█████████████   | 102/125 [00:21<00:04,  4.82it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 103/125 [00:21<00:04,  4.82it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 104/125 [00:21<00:04,  4.83it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 105/125 [00:21<00:04,  4.83it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 106/125 [00:21<00:03,  4.83it/s]
# Validation DataLoader 0:  86%|█████████████▋  | 107/125 [00:22<00:03,  4.83it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 108/125 [00:22<00:03,  4.84it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 109/125 [00:22<00:03,  4.84it/s]
# Validation DataLoader 0:  88%|██████████████  | 110/125 [00:22<00:03,  4.84it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 111/125 [00:22<00:02,  4.84it/s]
# Validation DataLoader 0:  90%|██████████████▎ | 112/125 [00:23<00:02,  4.84it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 113/125 [00:23<00:02,  4.84it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 114/125 [00:23<00:02,  4.84it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 115/125 [00:23<00:02,  4.85it/s]
# Validation DataLoader 0:  93%|██████████████▊ | 116/125 [00:23<00:01,  4.85it/s]
# Validation DataLoader 0:  94%|██████████████▉ | 117/125 [00:24<00:01,  4.85it/s]
# Validation DataLoader 0:  94%|███████████████ | 118/125 [00:24<00:01,  4.85it/s]
# Validation DataLoader 0:  95%|███████████████▏| 119/125 [00:24<00:01,  4.86it/s]
# Validation DataLoader 0:  96%|███████████████▎| 120/125 [00:24<00:01,  4.86it/s]
# Validation DataLoader 0:  97%|███████████████▍| 121/125 [00:24<00:00,  4.86it/s]
# Validation DataLoader 0:  98%|███████████████▌| 122/125 [00:25<00:00,  4.86it/s]
# Validation DataLoader 0:  98%|███████████████▋| 123/125 [00:25<00:00,  4.86it/s]
# Validation DataLoader 0:  99%|███████████████▊| 124/125 [00:25<00:00,  4.86it/s]
# Validation DataLoader 0: 100%|████████████████| 125/125 [00:25<00:00,  4.85it/s]
# Epoch 19: 100%|█| 500/500 [01:52<00:00,  4.43it/s, v_num=0, validation_loss=1.95
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/125 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/125 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏                 | 1/125 [00:00<00:01, 72.41it/s]
# Validation DataLoader 0:   2%|▎                 | 2/125 [00:00<00:13,  9.28it/s]
# Validation DataLoader 0:   2%|▍                 | 3/125 [00:00<00:16,  7.34it/s]
# Validation DataLoader 0:   3%|▌                 | 4/125 [00:00<00:17,  6.77it/s]
# Validation DataLoader 0:   4%|▋                 | 5/125 [00:00<00:18,  6.53it/s]
# Validation DataLoader 0:   5%|▊                 | 6/125 [00:00<00:18,  6.36it/s]
# Validation DataLoader 0:   6%|█                 | 7/125 [00:01<00:19,  6.17it/s]
# Validation DataLoader 0:   6%|█▏                | 8/125 [00:01<00:19,  5.97it/s]
# Validation DataLoader 0:   7%|█▎                | 9/125 [00:01<00:19,  5.87it/s]
# Validation DataLoader 0:   8%|█▎               | 10/125 [00:01<00:19,  5.79it/s]
# Validation DataLoader 0:   9%|█▍               | 11/125 [00:01<00:20,  5.68it/s]
# Validation DataLoader 0:  10%|█▋               | 12/125 [00:02<00:20,  5.64it/s]
# Validation DataLoader 0:  10%|█▊               | 13/125 [00:02<00:19,  5.63it/s]
# Validation DataLoader 0:  11%|█▉               | 14/125 [00:02<00:19,  5.60it/s]
# Validation DataLoader 0:  12%|██               | 15/125 [00:02<00:19,  5.57it/s]
# Validation DataLoader 0:  13%|██▏              | 16/125 [00:02<00:19,  5.56it/s]
# Validation DataLoader 0:  14%|██▎              | 17/125 [00:03<00:19,  5.52it/s]
# Validation DataLoader 0:  14%|██▍              | 18/125 [00:03<00:19,  5.48it/s]
# Validation DataLoader 0:  15%|██▌              | 19/125 [00:03<00:19,  5.43it/s]
# Validation DataLoader 0:  16%|██▋              | 20/125 [00:03<00:19,  5.39it/s]
# Validation DataLoader 0:  17%|██▊              | 21/125 [00:03<00:19,  5.34it/s]
# Validation DataLoader 0:  18%|██▉              | 22/125 [00:04<00:19,  5.32it/s]
# Validation DataLoader 0:  18%|███▏             | 23/125 [00:04<00:19,  5.32it/s]
# Validation DataLoader 0:  19%|███▎             | 24/125 [00:04<00:19,  5.29it/s]
# Validation DataLoader 0:  20%|███▍             | 25/125 [00:04<00:18,  5.29it/s]
# Validation DataLoader 0:  21%|███▌             | 26/125 [00:04<00:18,  5.29it/s]
# Validation DataLoader 0:  22%|███▋             | 27/125 [00:05<00:18,  5.27it/s]
# Validation DataLoader 0:  22%|███▊             | 28/125 [00:05<00:18,  5.28it/s]
# Validation DataLoader 0:  23%|███▉             | 29/125 [00:05<00:18,  5.27it/s]
# Validation DataLoader 0:  24%|████             | 30/125 [00:05<00:18,  5.27it/s]
# Validation DataLoader 0:  25%|████▏            | 31/125 [00:05<00:17,  5.25it/s]
# Validation DataLoader 0:  26%|████▎            | 32/125 [00:06<00:17,  5.23it/s]
# Validation DataLoader 0:  26%|████▍            | 33/125 [00:06<00:17,  5.23it/s]
# Validation DataLoader 0:  27%|████▌            | 34/125 [00:06<00:18,  4.94it/s]
# Validation DataLoader 0:  28%|████▊            | 35/125 [00:07<00:19,  4.53it/s]
# Validation DataLoader 0:  29%|████▉            | 36/125 [00:07<00:19,  4.53it/s]
# Validation DataLoader 0:  30%|█████            | 37/125 [00:08<00:19,  4.53it/s]
# Validation DataLoader 0:  30%|█████▏           | 38/125 [00:08<00:19,  4.53it/s]
# Validation DataLoader 0:  31%|█████▎           | 39/125 [00:08<00:18,  4.54it/s]
# Validation DataLoader 0:  32%|█████▍           | 40/125 [00:08<00:18,  4.56it/s]
# Validation DataLoader 0:  33%|█████▌           | 41/125 [00:08<00:18,  4.56it/s]
# Validation DataLoader 0:  34%|█████▋           | 42/125 [00:09<00:18,  4.57it/s]
# Validation DataLoader 0:  34%|█████▊           | 43/125 [00:09<00:17,  4.58it/s]
# Validation DataLoader 0:  35%|█████▉           | 44/125 [00:09<00:17,  4.59it/s]
# Validation DataLoader 0:  36%|██████           | 45/125 [00:09<00:17,  4.61it/s]
# Validation DataLoader 0:  37%|██████▎          | 46/125 [00:09<00:17,  4.62it/s]
# Validation DataLoader 0:  38%|██████▍          | 47/125 [00:10<00:16,  4.63it/s]
# Validation DataLoader 0:  38%|██████▌          | 48/125 [00:10<00:16,  4.64it/s]
# Validation DataLoader 0:  39%|██████▋          | 49/125 [00:10<00:16,  4.65it/s]
# Validation DataLoader 0:  40%|██████▊          | 50/125 [00:10<00:16,  4.65it/s]
# Validation DataLoader 0:  41%|██████▉          | 51/125 [00:10<00:15,  4.65it/s]
# Validation DataLoader 0:  42%|███████          | 52/125 [00:11<00:15,  4.66it/s]
# Validation DataLoader 0:  42%|███████▏         | 53/125 [00:11<00:15,  4.68it/s]
# Validation DataLoader 0:  43%|███████▎         | 54/125 [00:11<00:15,  4.68it/s]
# Validation DataLoader 0:  44%|███████▍         | 55/125 [00:11<00:14,  4.69it/s]
# Validation DataLoader 0:  45%|███████▌         | 56/125 [00:11<00:14,  4.69it/s]
# Validation DataLoader 0:  46%|███████▊         | 57/125 [00:12<00:14,  4.70it/s]
# Validation DataLoader 0:  46%|███████▉         | 58/125 [00:12<00:14,  4.70it/s]
# Validation DataLoader 0:  47%|████████         | 59/125 [00:12<00:14,  4.70it/s]
# Validation DataLoader 0:  48%|████████▏        | 60/125 [00:12<00:13,  4.71it/s]
# Validation DataLoader 0:  49%|████████▎        | 61/125 [00:12<00:13,  4.71it/s]
# Validation DataLoader 0:  50%|████████▍        | 62/125 [00:13<00:13,  4.71it/s]
# Validation DataLoader 0:  50%|████████▌        | 63/125 [00:13<00:13,  4.71it/s]
# Validation DataLoader 0:  51%|████████▋        | 64/125 [00:13<00:12,  4.72it/s]
# Validation DataLoader 0:  52%|████████▊        | 65/125 [00:13<00:12,  4.73it/s]
# Validation DataLoader 0:  53%|████████▉        | 66/125 [00:13<00:12,  4.73it/s]
# Validation DataLoader 0:  54%|█████████        | 67/125 [00:14<00:12,  4.74it/s]
# Validation DataLoader 0:  54%|█████████▏       | 68/125 [00:14<00:12,  4.74it/s]
# Validation DataLoader 0:  55%|█████████▍       | 69/125 [00:14<00:11,  4.75it/s]
# Validation DataLoader 0:  56%|█████████▌       | 70/125 [00:14<00:11,  4.76it/s]
# Validation DataLoader 0:  57%|█████████▋       | 71/125 [00:14<00:11,  4.76it/s]
# Validation DataLoader 0:  58%|█████████▊       | 72/125 [00:15<00:11,  4.77it/s]
# Validation DataLoader 0:  58%|█████████▉       | 73/125 [00:15<00:10,  4.77it/s]
# Validation DataLoader 0:  59%|██████████       | 74/125 [00:15<00:10,  4.78it/s]
# Validation DataLoader 0:  60%|██████████▏      | 75/125 [00:15<00:10,  4.78it/s]
# Validation DataLoader 0:  61%|██████████▎      | 76/125 [00:15<00:10,  4.79it/s]
# Validation DataLoader 0:  62%|██████████▍      | 77/125 [00:16<00:10,  4.80it/s]
# Validation DataLoader 0:  62%|██████████▌      | 78/125 [00:16<00:09,  4.80it/s]
# Validation DataLoader 0:  63%|██████████▋      | 79/125 [00:16<00:09,  4.80it/s]
# Validation DataLoader 0:  64%|██████████▉      | 80/125 [00:16<00:09,  4.80it/s]
# Validation DataLoader 0:  65%|███████████      | 81/125 [00:16<00:09,  4.81it/s]
# Validation DataLoader 0:  66%|███████████▏     | 82/125 [00:17<00:08,  4.81it/s]
# Validation DataLoader 0:  66%|███████████▎     | 83/125 [00:17<00:08,  4.82it/s]
# Validation DataLoader 0:  67%|███████████▍     | 84/125 [00:17<00:08,  4.82it/s]
# Validation DataLoader 0:  68%|███████████▌     | 85/125 [00:17<00:08,  4.82it/s]
# Validation DataLoader 0:  69%|███████████▋     | 86/125 [00:17<00:08,  4.82it/s]
# Validation DataLoader 0:  70%|███████████▊     | 87/125 [00:18<00:07,  4.82it/s]
# Validation DataLoader 0:  70%|███████████▉     | 88/125 [00:18<00:07,  4.81it/s]
# Validation DataLoader 0:  71%|████████████     | 89/125 [00:18<00:07,  4.82it/s]
# Validation DataLoader 0:  72%|████████████▏    | 90/125 [00:18<00:07,  4.82it/s]
# Validation DataLoader 0:  73%|████████████▍    | 91/125 [00:18<00:07,  4.82it/s]
# Validation DataLoader 0:  74%|████████████▌    | 92/125 [00:19<00:06,  4.82it/s]
# Validation DataLoader 0:  74%|████████████▋    | 93/125 [00:19<00:06,  4.82it/s]
# Validation DataLoader 0:  75%|████████████▊    | 94/125 [00:19<00:06,  4.83it/s]
# Validation DataLoader 0:  76%|████████████▉    | 95/125 [00:19<00:06,  4.83it/s]
# Validation DataLoader 0:  77%|█████████████    | 96/125 [00:19<00:05,  4.84it/s]
# Validation DataLoader 0:  78%|█████████████▏   | 97/125 [00:20<00:05,  4.85it/s]
# Validation DataLoader 0:  78%|█████████████▎   | 98/125 [00:20<00:05,  4.85it/s]
# Validation DataLoader 0:  79%|█████████████▍   | 99/125 [00:20<00:05,  4.85it/s]
# Validation DataLoader 0:  80%|████████████▊   | 100/125 [00:20<00:05,  4.85it/s]
# Validation DataLoader 0:  81%|████████████▉   | 101/125 [00:20<00:04,  4.86it/s]
# Validation DataLoader 0:  82%|█████████████   | 102/125 [00:20<00:04,  4.86it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 103/125 [00:21<00:04,  4.87it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 104/125 [00:21<00:04,  4.87it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 105/125 [00:21<00:04,  4.88it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 106/125 [00:21<00:03,  4.88it/s]
# Validation DataLoader 0:  86%|█████████████▋  | 107/125 [00:21<00:03,  4.89it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 108/125 [00:22<00:03,  4.89it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 109/125 [00:22<00:03,  4.89it/s]
# Validation DataLoader 0:  88%|██████████████  | 110/125 [00:22<00:03,  4.89it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 111/125 [00:22<00:02,  4.90it/s]
# Validation DataLoader 0:  90%|██████████████▎ | 112/125 [00:22<00:02,  4.90it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 113/125 [00:23<00:02,  4.90it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 114/125 [00:23<00:02,  4.91it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 115/125 [00:23<00:02,  4.91it/s]
# Validation DataLoader 0:  93%|██████████████▊ | 116/125 [00:23<00:01,  4.91it/s]
# Validation DataLoader 0:  94%|██████████████▉ | 117/125 [00:23<00:01,  4.91it/s]
# Validation DataLoader 0:  94%|███████████████ | 118/125 [00:23<00:01,  4.92it/s]
# Validation DataLoader 0:  95%|███████████████▏| 119/125 [00:24<00:01,  4.93it/s]
# Validation DataLoader 0:  96%|███████████████▎| 120/125 [00:24<00:01,  4.93it/s]
# Validation DataLoader 0:  97%|███████████████▍| 121/125 [00:24<00:00,  4.93it/s]
# Validation DataLoader 0:  98%|███████████████▌| 122/125 [00:24<00:00,  4.93it/s]
# Validation DataLoader 0:  98%|███████████████▋| 123/125 [00:24<00:00,  4.93it/s]
# Validation DataLoader 0:  99%|███████████████▊| 124/125 [00:25<00:00,  4.92it/s]
# Validation DataLoader 0: 100%|████████████████| 125/125 [00:25<00:00,  4.92it/s]
# Epoch 19: 100%|█| 500/500 [02:18<00:00,  3.61it/s, v_num=0, validation_loss=2.02INFO: `Trainer.fit` stopped: `max_epochs=20` reached.
# Epoch 19: 100%|█| 500/500 [02:18<00:00,  3.60it/s, v_num=0, validation_loss=2.02
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# Testing DataLoader 0: 100%|███████████████████| 125/125 [00:41<00:00,  3.01it/s]
# Test Accuracy :  0.7155

# %%
# zip unzip
#!unzip -q /kaggle/input/inaturalist-12k.zip -d /kaggle/working/inaturalist-12k
# Out:
# unzip:  cannot find or open /kaggle/input/inaturalist-12k.zip, /kaggle/input/inaturalist-12k.zip.zip or /kaggle/input/inaturalist-12k.zip.ZIP.

# %%
# train file below

# %%
# %%writefile train_arguments_partb.py
import argparse

def arguments():
    '''
      Parameters:
        None
      Returns :
        A parser object
      Function:
        Does command line argument parsing and returns the arguments passed
    '''
    commandLineArgument = argparse.ArgumentParser(description='Model Parameters')
    commandLineArgument.add_argument('-r','--root', help="Absolute path of the dataset")
    commandLineArgument.add_argument('-e','--epochs', type=int, help="Number of epochs to train neural network")
    commandLineArgument.add_argument('-b','--batch', type=int, help="Batch size to divide the dataset")
    commandLineArgument.add_argument('-lr','--learning', type=float, help="Learning rate to train the model")
    commandLineArgument.add_argument('-fr','--freezed', type=int, help="Number of layers freezed from the beginning")
    commandLineArgument.add_argument('-t','--test', type=int, choices=[0,1], help="choices: [0,1]")
    
    return commandLineArgument.parse_args()
# Out:
# Writing train_arguments_partb.py

# %%
# %%writefile train_partb.py
import torch
from Create_DataLoader import DatasetLoader_create
import ModelPreTrained_test
import lightning as pl
import wandb
import warnings
from train_arguments_partb import arguments

warnings.filterwarnings("ignore")

'''login to wandb to generate plot'''
wandb.login()

'''setting the device to gpu if avaiable'''
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

'''helper class to execute fine-tuning and optional testing'''
class PreTrained:
    def run(root, epochs, batch_size, learning_rate, freezed, test):
        '''
        Parameters:
            root : absolute path of the dataset
            epochs : number of epochs to run
            batch_size : batch size to split the dataset
            learning_rate : learning rate used to train the model
            freezed : number of layers freezed starting from the input layer
            test : boolean variable denoting whether or not to test the model 
        Returns :
            None
        Function:
            Executes the Fine Tuning on the model
        '''

        '''loads dataset'''
        dataLoader = DatasetLoader_create(root=root, batch_size=batch_size)
        trainLoader, valLoader, testLoader = dataLoader.data_loaders()
        
        '''setting number of output classes to 10'''
        numOfOutputClasses = 10

        '''creating the object of the class and a trainer on it'''
        preTrainedModel = ModelPreTrained_test.FineTuningModel(numOfOutputClasses, freezed, learning_rate)

        # trainer = pl.Trainer(max_epochs=epochs)
        trainer = pl.Trainer(
            max_epochs=epochs, 
            strategy='ddp_find_unused_parameters_true',
            devices=1,
            enable_progress_bar=True
        )


        '''executing train and validation steps'''
        trainer.fit(preTrainedModel, trainLoader, valLoader)

        '''if prompted then executing test step'''
        if test == 1:
            trainer.test(preTrainedModel, testLoader)
            print("Test Accuracy : ", preTrainedModel.test_accuracy / len(testLoader))

'''main driver function'''
def main():
    '''default values of each of the hyperparameter. Since there was a positive corelation in Part_A co-relation summary table, I tried running with higher number of epochs in Part B.'''
    epochs = 20
    batch_size = 32
    learning_rate = 1e-4
    freezed = 5
    test = 0
    root = '/kaggle/input/inaturalist-12k/nature_12K_dataset/inaturalist_12K'

    '''call to argument function to get the arguments'''
    args = arguments()

    '''checking if a particular argument is passed through command line or not and updating the values accordingly'''
    if args.epochs is not None:
        epochs = args.epochs
    if args.batch is not None:
        batch_size = args.batch
    if args.learning is not None:
        learning_rate = args.learning
    if args.freezed is not None:
        freezed = args.freezed
    if args.test is not None:
        test = args.test
    if args.root is not None:
        root = args.root

    '''calling the run method with the parameters'''
    PreTrained.run(root, epochs, batch_size, learning_rate, freezed, test)
    wandb.finish()

if __name__ == '__main__':
    main()
# Out:
# Overwriting train_partb.py

# %%
# !python train_partb.py
# Out:
# wandb: Currently logged in as: cs24m015 (cs24m015-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# INFO: You are using the plain ModelCheckpoint callback. Consider using LitModelCheckpoint which with seamless uploading to Model registry.
# INFO: GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO: Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# INFO: ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# 2025-04-18 17:51:38.500143: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744998698.522118     225 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744998698.528833     225 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# INFO:
#   | Name                | Type               | Params | Mode
# -------------------------------------------------------------------
# 0 | model               | GoogLeNet          | 6.6 M  | train
# 1 | feature_extractor   | Sequential         | 5.6 M  | eval
# 2 | outputLayer         | Linear             | 10.2 K | train
# 3 | criterion           | CrossEntropyLoss   | 0      | train
# 4 | training_accuracy   | MulticlassAccuracy | 0      | train
# 5 | validation_accuracy | MulticlassAccuracy | 0      | train
# -------------------------------------------------------------------
# 3.4 M     Trainable params
# 3.3 M     Non-trainable params
# 6.6 M     Total params
# 26.541    Total estimated model params size (MB)
# 6         Modules in train mode
# 223       Modules in eval mode
# Epoch 0: 100%|███████████████████████| 250/250 [03:03<00:00,  1.37it/s, v_num=2]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                        | 0/63 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/63 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎                  | 1/63 [00:00<00:00, 71.02it/s]
# Validation DataLoader 0:   3%|▌                  | 2/63 [00:00<00:13,  4.53it/s]
# Validation DataLoader 0:   5%|▉                  | 3/63 [00:01<00:20,  2.88it/s]
# Validation DataLoader 0:   6%|█▏                 | 4/63 [00:01<00:29,  2.01it/s]
# Validation DataLoader 0:   8%|█▌                 | 5/63 [00:03<00:38,  1.50it/s]
# Validation DataLoader 0:  10%|█▊                 | 6/63 [00:04<00:38,  1.49it/s]
# Validation DataLoader 0:  11%|██                 | 7/63 [00:04<00:38,  1.46it/s]
# Validation DataLoader 0:  13%|██▍                | 8/63 [00:05<00:37,  1.48it/s]
# Validation DataLoader 0:  14%|██▋                | 9/63 [00:06<00:36,  1.48it/s]
# Validation DataLoader 0:  16%|██▊               | 10/63 [00:06<00:36,  1.47it/s]
# Validation DataLoader 0:  17%|███▏              | 11/63 [00:07<00:35,  1.45it/s]
# Validation DataLoader 0:  19%|███▍              | 12/63 [00:08<00:34,  1.46it/s]
# Validation DataLoader 0:  21%|███▋              | 13/63 [00:08<00:34,  1.45it/s]
# Validation DataLoader 0:  22%|████              | 14/63 [00:09<00:33,  1.46it/s]
# Validation DataLoader 0:  24%|████▎             | 15/63 [00:10<00:32,  1.47it/s]
# Validation DataLoader 0:  25%|████▌             | 16/63 [00:10<00:31,  1.48it/s]
# Validation DataLoader 0:  27%|████▊             | 17/63 [00:11<00:30,  1.49it/s]
# Validation DataLoader 0:  29%|█████▏            | 18/63 [00:12<00:30,  1.48it/s]
# Validation DataLoader 0:  30%|█████▍            | 19/63 [00:12<00:29,  1.48it/s]
# Validation DataLoader 0:  32%|█████▋            | 20/63 [00:13<00:28,  1.48it/s]
# Validation DataLoader 0:  33%|██████            | 21/63 [00:14<00:28,  1.49it/s]
# Validation DataLoader 0:  35%|██████▎           | 22/63 [00:14<00:27,  1.49it/s]
# Validation DataLoader 0:  37%|██████▌           | 23/63 [00:15<00:26,  1.49it/s]
# Validation DataLoader 0:  38%|██████▊           | 24/63 [00:16<00:26,  1.49it/s]
# Validation DataLoader 0:  40%|███████▏          | 25/63 [00:16<00:25,  1.49it/s]
# Validation DataLoader 0:  41%|███████▍          | 26/63 [00:17<00:24,  1.50it/s]
# Validation DataLoader 0:  43%|███████▋          | 27/63 [00:17<00:23,  1.50it/s]
# Validation DataLoader 0:  44%|████████          | 28/63 [00:18<00:23,  1.50it/s]
# Validation DataLoader 0:  46%|████████▎         | 29/63 [00:19<00:22,  1.51it/s]
# Validation DataLoader 0:  48%|████████▌         | 30/63 [00:19<00:21,  1.51it/s]
# Validation DataLoader 0:  49%|████████▊         | 31/63 [00:20<00:21,  1.51it/s]
# Validation DataLoader 0:  51%|█████████▏        | 32/63 [00:21<00:20,  1.52it/s]
# Validation DataLoader 0:  52%|█████████▍        | 33/63 [00:21<00:19,  1.52it/s]
# Validation DataLoader 0:  54%|█████████▋        | 34/63 [00:22<00:19,  1.52it/s]
# Validation DataLoader 0:  56%|██████████        | 35/63 [00:23<00:18,  1.52it/s]
# Validation DataLoader 0:  57%|██████████▎       | 36/63 [00:23<00:17,  1.52it/s]
# Validation DataLoader 0:  59%|██████████▌       | 37/63 [00:24<00:17,  1.52it/s]
# Validation DataLoader 0:  60%|██████████▊       | 38/63 [00:25<00:16,  1.51it/s]
# Validation DataLoader 0:  62%|███████████▏      | 39/63 [00:25<00:15,  1.51it/s]
# Validation DataLoader 0:  63%|███████████▍      | 40/63 [00:26<00:15,  1.51it/s]
# Validation DataLoader 0:  65%|███████████▋      | 41/63 [00:27<00:14,  1.51it/s]
# Validation DataLoader 0:  67%|████████████      | 42/63 [00:27<00:13,  1.51it/s]
# Validation DataLoader 0:  68%|████████████▎     | 43/63 [00:28<00:13,  1.51it/s]
# Validation DataLoader 0:  70%|████████████▌     | 44/63 [00:29<00:12,  1.51it/s]
# Validation DataLoader 0:  71%|████████████▊     | 45/63 [00:29<00:11,  1.52it/s]
# Validation DataLoader 0:  73%|█████████████▏    | 46/63 [00:30<00:11,  1.52it/s]
# Validation DataLoader 0:  75%|█████████████▍    | 47/63 [00:31<00:10,  1.51it/s]
# Validation DataLoader 0:  76%|█████████████▋    | 48/63 [00:31<00:09,  1.51it/s]
# Validation DataLoader 0:  78%|██████████████    | 49/63 [00:32<00:09,  1.52it/s]
# Validation DataLoader 0:  79%|██████████████▎   | 50/63 [00:33<00:08,  1.52it/s]
# Validation DataLoader 0:  81%|██████████████▌   | 51/63 [00:34<00:08,  1.48it/s]
# Validation DataLoader 0:  83%|██████████████▊   | 52/63 [00:35<00:07,  1.48it/s]
# Validation DataLoader 0:  84%|███████████████▏  | 53/63 [00:35<00:06,  1.48it/s]
# Validation DataLoader 0:  86%|███████████████▍  | 54/63 [00:36<00:06,  1.48it/s]
# Validation DataLoader 0:  87%|███████████████▋  | 55/63 [00:37<00:05,  1.48it/s]
# Validation DataLoader 0:  89%|████████████████  | 56/63 [00:37<00:04,  1.48it/s]
# Validation DataLoader 0:  90%|████████████████▎ | 57/63 [00:38<00:04,  1.48it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 58/63 [00:39<00:03,  1.48it/s]
# Validation DataLoader 0:  94%|████████████████▊ | 59/63 [00:39<00:02,  1.49it/s]
# Validation DataLoader 0:  95%|█████████████████▏| 60/63 [00:40<00:02,  1.49it/s]
# Validation DataLoader 0:  97%|█████████████████▍| 61/63 [00:40<00:01,  1.49it/s]
# Validation DataLoader 0:  98%|█████████████████▋| 62/63 [00:41<00:00,  1.49it/s]
# Validation DataLoader 0: 100%|██████████████████| 63/63 [00:42<00:00,  1.50it/s]
# Epoch 1:   6%| | 14/250 [00:06<01:43,  2.27it/s, v_num=2, validation_loss=0.989,^CA
# INFO:
# Detected KeyboardInterrupt, attempting graceful shutdown ...
